# %% [markdown]
# # 03. Model Evaluation
#
# ## Evaluating LLM Performance
#
# We evaluate the Gemini Pro Vision responses against a small validation set of verified crop disease images.

# %%
import json

# Mock Validation Data
validation_set = [
    {"image": "test_tomato_1.jpg", "ground_truth": "Early Blight"},
    {"image": "test_potato_2.jpg", "ground_truth": "Late Blight"}
]

# Evaluation Loop (Conceptual)
accuracy_count = 0
total = len(validation_set)

print(f"Evaluating on {total} samples...")
# for item in validation_set:
#     pred = predict_disease(item['image'])
#     if pred == item['ground_truth']:
#         accuracy_count += 1

# print(f"Accuracy: {accuracy_count/total * 100}%")
